# %% [markdown]
# # Visualizing crypto market structure
# Adapted from https://scikit-learn.org/stable/auto_examples/applications/plot_stock_market.html#sphx-glr-auto-examples-applications-plot-stock-market-py
#
# This example employs several unsupervised learning techniques to extract
# the stock market structure from variations in historical quotes.
#
# The quantity that we use is the daily variation in quote price: quotes
# that are linked tend to fluctuate in relation to each other during a day.

# %%
import time
import json

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import numpy as np
import pandas as pd
import requests
from sklearn import covariance, cluster, manifold

# %% [markdown]
# We examine Coindesk Market Index
# [coindesk](https://www.coindesk.com/indices/cmis).

# %%
constituents = pd.read_csv("constituents_coindesk_market_index.csv")
constituents = constituents.rename(columns=lambda x: x.lower())

# %%
with open('coingecko_list.json') as f:
    cg_data = json.load(f)

cg_names = pd.DataFrame.from_records(cg_data)
cg_names = cg_names.rename(columns={'name': 'cg_name'})

# %%
constituents = constituents.merge(cg_names, how="left", on='symbol')

# %%
constituents.to_csv("cg_constituents.csv")

# %%
constituents = pd.read_csv("cg_constituents_2.csv", index_col=0)

# %%
constituents
# Out:
#     symbol               name              dacs sector dacs industry group  \
# 0    1inch      1inch Network                     DeFi           Exchanges
# 1     aave               Aave                     DeFi     Credit Platform
# 2      aca        Acala Token  Smart Contract Platform             Layer 1
# 3      ach        Alchemy Pay                 Currency                BaaS
# 4      acs    Access Protocol  Culture & Entertainment               Media
# ..     ...                ...                      ...                 ...
# 279    xyo                XYO                Computing              Oracle
# 280    yfi      yearn.finance                     DeFi               Yield
# 281    ygg  Yield Guild Games  Culture & Entertainment           Metaverse
# 282    zec              Zcash                 Currency             Private
# 283    zrx                 0x                     DeFi           Exchanges
#
#            dacs industry  reconstitution weight                 id  \
# 0      Exchanges (Other)               0.032945              1inch
# 1    Lending / Borrowing               0.108995               aave
# 2                Layer 1               0.006482              acala
# 3               Payments               0.011424        alchemy-pay
# 4                 Social               0.007609    access-protocol
# ..                   ...                    ...                ...
# 279               Oracle               0.006356        xyo-network
# 280                Yield               0.019512      yearn-finance
# 281   Metaverse Platform               0.009636  yield-guild-games
# 282              Private               0.035552              zcash
# 283    Exchanges (Other)               0.021804                 0x
#
#                cg_name
# 0                1inch
# 1                 Aave
# 2                Acala
# 3          Alchemy Pay
# 4      Access Protocol
# ..                 ...
# 279        XYO Network
# 280      yearn.finance
# 281  Yield Guild Games
# 282              Zcash
# 283        0x Protocol
#
# [184 rows x 8 columns]

# %%
constituents[constituents.symbol.duplicated()]
# Out:
# Empty DataFrame
# Columns: [symbol, name, dacs sector, dacs industry group, dacs industry, reconstitution weight, id, cg_name]
# Index: []

# %%
start = pd.Timestamp("2022-12-01T12:00:00")
end  = pd.Timestamp("2023-12-01T12:00:00")

results = []
for _, row in constituents.iterrows():
    time.sleep(21)
    token_id = row['id']
    name = row['name']
    print(f"token_id {token_id}")
    r = requests.get(f"https://api.coingecko.com/api/v3/coins/{token_id}/market_chart/range?vs_currency=USD&from={start.timestamp()}&to={end.timestamp()}")
    print(f"getting data for name {name}")
    resp = r.json()
    data = resp.get('prices')
    if (data is None) or (len(data) == 0):
        print(f"no data for ticker {name}")
        date_range = pd.date_range(start, end)
        nan_prices = np.empty((date_range.shape[0], ))
        nan_prices[:] = np.nan
        prices = pd.DataFrame({'date' : date_range, 'close': nan_prices})
    else:
        prices = pd.DataFrame(resp.get('prices')) 
        prices.columns = ["date", 'price']
    prices = prices.sort_values(by='date')
    prices["date"] = pd.to_datetime(prices.date, unit='ms', origin='unix')
    prices["name"] = name
    results.append(prices)

combined_data = pd.concat(results)
# Out:
# token_id 1inch
# getting data for name 1inch Network
# token_id aave
# getting data for name Aave
# token_id acala
# getting data for name Acala Token
# token_id alchemy-pay
# getting data for name Alchemy Pay
# token_id access-protocol
# getting data for name Access Protocol
# token_id cardano
# getting data for name Cardano
# token_id aergo
# getting data for name Aergo
# token_id adventure-gold
# getting data for name Adventure Gold
# token_id akash-network
# getting data for name Akash Network
# token_id alchemix
# getting data for name Alchemix
# token_id algorand
# getting data for name Algorand
# token_id alethea-artificial-liquid-intelligence-token
# getting data for name Artificial Liquid Intelligence
# token_id my-neighbor-alice
# getting data for name My Neighbor Alice
# token_id alphacoin
# getting data for name Alpha Coin
# token_id amp-token
# getting data for name Amp
# token_id ankr
# getting data for name Ankr
# token_id aragon
# getting data for name Aragon
# token_id apecoin
# getting data for name ApeCoin
# token_id api3
# getting data for name API3
# token_id aptos
# getting data for name Aptos
# token_id arbitrum
# getting data for name Arbitrum
# token_id arpa
# getting data for name ARPA
# token_id astar
# getting data for name Astar
# token_id cosmos
# getting data for name Cosmos
# token_id audius
# getting data for name Audius
# token_id aurora-near
# getting data for name Aurora
# token_id avalanche-2
# getting data for name Avalanche
# token_id axelar
# getting data for name Axelar
# token_id axie-infinity
# getting data for name Axie Infinity
# token_id badger-dao
# getting data for name Badger DAO
# token_id balancer
# getting data for name Balancer
# token_id band-protocol
# getting data for name Band Protocol
# token_id basic-attention-token
# getting data for name Basic Attention Token
# token_id bitcoin-cash
# getting data for name Bitcoin Cash
# token_id biconomy
# getting data for name Biconomy
# token_id blur
# getting data for name Blur
# token_id bluzelle
# getting data for name Bluzelle
# token_id bancor
# getting data for name Bancor
# token_id barnbridge
# getting data for name BarnBridge
# token_id bitcoin
# getting data for name Bitcoin
# token_id coin98
# getting data for name Coin98
# token_id celer-network
# getting data for name Celer Network
# token_id chromaway
# getting data for name Chromia
# token_id chiliz
# getting data for name Chiliz
# token_id compound-governance-token
# getting data for name Compound
# token_id coti
# getting data for name COTI
# token_id covalent
# getting data for name Covalent
# token_id crypto-com-chain
# getting data for name Cronos
# token_id curve-dao-token
# getting data for name Curve DAO Token
# token_id cartesi
# getting data for name Cartesi
# token_id civic
# getting data for name Civic
# token_id convex-finance
# getting data for name Convex Finance
# token_id mines-of-dalarnia
# getting data for name Mines of Dalarnia
# token_id dash
# getting data for name Dash
# token_id dia-data
# getting data for name DIA
# token_id dogecoin
# getting data for name Dogecoin
# token_id polkadot
# getting data for name Polkadot
# token_id dydx-chain
# getting data for name dYdX
# token_id elrond-erd-2
# getting data for name MultiversX
# token_id dogelon-mars
# getting data for name Dogelon Mars
# token_id enjincoin
# getting data for name Enjin Coin
# token_id ethereum-name-service
# getting data for name Ethereum Name Service
# token_id eos
# getting data for name EOS
# token_id ethernity-chain
# getting data for name Ethernity Chain
# token_id ethereum-classic
# getting data for name Ethereum Classic
# token_id ethereum
# getting data for name Ethereum
# token_id ethereum-pow-iou
# getting data for name EthereumPoW
# token_id fetch-ai
# getting data for name Fetch.ai
# token_id filecoin
# getting data for name Filecoin
# token_id flow
# getting data for name Flow
# token_id flare-networks
# getting data for name Flare
# token_id ampleforth-governance-token
# getting data for name Ampleforth Governance Token
# token_id fantom
# getting data for name Fantom
# token_id frax-share
# getting data for name Frax Share
# token_id project-galaxy
# getting data for name Galxe
# token_id gala
# getting data for name Gala
# token_id aavegotchi
# getting data for name Aavegotchi
# token_id golem
# getting data for name Golem
# token_id moonbeam
# getting data for name Moonbeam
# token_id stepn
# getting data for name GMT
# token_id gmx
# getting data for name GMX
# token_id gnosis
# getting data for name Gnosis
# token_id gods-unchained
# getting data for name Gods Unchained
# token_id the-graph
# getting data for name The Graph
# token_id gitcoin
# getting data for name Gitcoin
# token_id hedera-hashgraph
# getting data for name Hedera
# token_id hashflow
# getting data for name Hashflow
# token_id highstreet
# getting data for name Highstreet
# token_id helium
# getting data for name Helium
# token_id internet-computer
# getting data for name Internet Computer
# token_id icon
# getting data for name ICON
# token_id aurora-dao
# getting data for name IDEX
# token_id illuvium
# getting data for name Illuvium
# token_id immutable-x
# getting data for name Immutable X
# token_id injective-protocol
# getting data for name Injective
# token_id iotex
# getting data for name IoTeX
# token_id jasmycoin
# getting data for name JasmyCoin
# token_id kava
# getting data for name Kava
# token_id kyber-network-crystal
# getting data for name Kyber Network Crystal
# token_id kusama
# getting data for name Kusama
# token_id lcx
# getting data for name LCX
# token_id lido-dao
# getting data for name Lido DAO
# token_id chainlink
# getting data for name Chainlink
# token_id litentry
# getting data for name Litentry
# token_id livepeer
# getting data for name Livepeer
# token_id liquity
# getting data for name Liquity
# token_id loopring
# getting data for name Loopring
# token_id lisk
# getting data for name Lisk
# token_id litecoin
# getting data for name Litecoin
# token_id terra-luna
# getting data for name Terra Luna Classic
# token_id terra-luna-2
# getting data for name Terra
# token_id magic
# getting data for name MAGIC
# token_id decentraland
# getting data for name Decentraland
# token_id mask-network
# getting data for name Mask Network
# token_id matic-network
# getting data for name Polygon
# token_id measurable-data-token
# getting data for name Measurable Data Token
# token_id metis-token
# getting data for name MetisDAO
# token_id mina-protocol
# getting data for name Mina
# token_id maker
# getting data for name Maker
# token_id melon
# getting data for name Enzyme
# token_id moonriver
# getting data for name Moonriver
# token_id near
# getting data for name NEAR Protocol
# token_id nkn
# getting data for name NKN
# token_id numeraire
# getting data for name Numeraire
# token_id ocean-protocol
# getting data for name Ocean Protocol
# token_id origin-protocol
# getting data for name Origin Protocol
# token_id omisego
# getting data for name OMG Network
# token_id optimism
# getting data for name Optimism
# token_id osmosis
# getting data for name Osmosis
# token_id orchid-protocol
# getting data for name Orchid
# token_id pepe
# getting data for name Pepe
# token_id perpetual-protocol
# getting data for name Perpetual Protocol
# token_id playdapp
# getting data for name PlayDapp
# token_id polkastarter
# getting data for name Polkastarter
# token_id marlin
# getting data for name Marlin
# token_id power-ledger
# getting data for name Powerledger
# token_id echelon-prime
# getting data for name Echelon Prime
# token_id vulcan-forged
# getting data for name Vulcan Forged PYR
# token_id quant-network
# getting data for name Quant
# token_id qredo
# getting data for name Qredo
# token_id qtum
# getting data for name Qtum
# token_id radicle
# getting data for name Radworks
# token_id superrare
# getting data for name SuperRare
# token_id ribbon-finance
# getting data for name Ribbon Finance
# token_id republic-protocol
# getting data for name Ren
# token_id request-network
# getting data for name Request
# token_id iexec-rlc
# getting data for name iExec RLC
# token_id render-token
# getting data for name Render Token
# token_id rocket-pool
# getting data for name Rocket Pool
# token_id thorchain
# getting data for name THORChain
# token_id the-sandbox
# getting data for name The Sandbox
# token_id siacoin
# getting data for name Siacoin
# token_id sei-network
# getting data for name Sei
# token_id shiba-inu
# getting data for name SHIBA INU
# token_id skale
# getting data for name SKALE
# token_id smooth-love-potion
# getting data for name Smooth Love Potion
# token_id status
# getting data for name Status
# token_id havven
# getting data for name Synthetix
# token_id solana
# getting data for name Solana
# token_id spell-token
# getting data for name Spell Token
# token_id stargate-finance
# getting data for name Stargate Finance
# token_id storj
# getting data for name Storj
# token_id blockstack
# getting data for name Stacks
# token_id sui
# getting data for name Sui
# token_id sushi
# getting data for name SushiSwap
# token_id synapse-2
# getting data for name Synapse
# token_id threshold-network-token
# getting data for name Threshold
# token_id tellor
# getting data for name Tellor
# token_id truefi
# getting data for name TrueFi
# token_id the-virtua-kolect
# getting data for name The Virtua Kolect
# token_id uma
# getting data for name UMA
# token_id unifi-protocol-dao
# getting data for name Unifi Protocol DAO
# token_id uniswap
# getting data for name Uniswap
# token_id vechain
# getting data for name VeChain
# token_id waves
# getting data for name Waves
# token_id woo-network
# getting data for name WOO Network
# token_id stellar
# getting data for name Stellar
# token_id ripple
# getting data for name XRP
# token_id tezos
# getting data for name Tezos
# token_id xyo-network
# getting data for name XYO
# token_id yearn-finance
# getting data for name yearn.finance
# token_id yield-guild-games
# getting data for name Yield Guild Games
# token_id zcash
# getting data for name Zcash
# token_id 0x
# getting data for name 0x

# %%
combined_data.to_csv('cg_price_data_total.csv')

# %%
combined_data.head()
# Out:
#         date     price           name
# 0 2022-12-02  0.512787  1inch Network
# 1 2022-12-03  0.505770  1inch Network
# 2 2022-12-04  0.489838  1inch Network
# 3 2022-12-05  0.500704  1inch Network
# 4 2022-12-06  0.485993  1inch Network

# %%
dataset = combined_data.pivot(index='date', columns='name', values='price')

# %%
dataset
# Out:
# name              0x  1inch Network      API3      ARPA       Aave  \
# date
# 2022-12-02  0.194349       0.512787  1.475673  0.027956  63.589064
# 2022-12-03  0.193552       0.505770  1.507737  0.028853  65.527824
# 2022-12-04  0.190112       0.489838  1.463525  0.028155  62.874587
# 2022-12-05  0.197506       0.500704  1.476821  0.028863  64.518508
# 2022-12-06  0.191915       0.485993  1.451414  0.028394  64.355277
# ...              ...            ...       ...       ...        ...
# 2023-11-27  0.401705       0.355181  1.461461  0.051936  98.052293
#  'Flare',
#  'Pepe',
#  'Sei',
#  'Sui',
#  'dYdX']

# %%
dataset = dataset.dropna(axis=1, how='any')

# %%
dataset.shape
# Out:
# (365, 175)

# %%
token_id  = "ada-the-dog"
start = pd.Timestamp("2022-12-01T12:00:00")
end  = pd.Timestamp("2023-12-01T12:00:00")
r = requests.get(f"https://api.coingecko.com/api/v3/coins/{token_id}/market_chart/range?vs_currency=USD&from={start.timestamp()}&to={end.timestamp()}")
resp = r.json()    
print(resp)
# Out:
# {'prices': [], 'market_caps': [], 'total_volumes': []}

# %%
constituents['ticker'] = constituents['Symbol'].str.upper() + "-USD"

# %%
constituents[constituents.name == "Cardano"]
# Out:
#   symbol     name              dacs sector dacs industry group dacs industry  \
# 7    ada  Cardano  Smart Contract Platform             Layer 1       Layer 1
# 8    ada  Cardano  Smart Contract Platform             Layer 1       Layer 1
# 9    ada  Cardano  Smart Contract Platform             Layer 1       Layer 1
#
#    reconstitution weight                   id              cg_name
# 7                1.52029          ada-the-dog          ADA the Dog
# 8                1.52029  binance-peg-cardano  Binance-Peg Cardano
# 9                1.52029              cardano              Cardano

# %%
constituents['DACS Sector'].unique()
# Out:
# array(['DeFi', 'Smart Contract Platform', 'Currency',
#        'Culture & Entertainment', 'Computing', 'Digitization'],
#       dtype=object)

# %%
f"https://api.pro.coinbase.com/products/{ticker}/candles?start={start}&end={end}&granularity=86400"
# Out:
# 'https://api.pro.coinbase.com/products/1INCH-USD/candles?start=2022-12-01 12:00:00&end=2023-06-01 12:00:00&granularity=86400'

# %%
def get_prices(ticker: str, start: pd.Timestamp, end: pd.Timestamp) -> pd.DataFrame:
    r = requests.get(f"https://api.pro.coinbase.com/products/{ticker}/candles?start={start.isoformat()}&end={end.isoformat()}&granularity=86400")
    resp = r.json()
    if isinstance(resp, list) and len(resp) > 0:
        print(f"found data from {ticker}")
        prices = pd.DataFrame(resp)
        prices.columns = ['time', 'open', 'high', 'low', 'close', 'volume']
        prices['date'] = pd.to_datetime(prices['time'], origin="unix", unit='s')
    else:
        print(f"no data for ticker {ticker}")
        date_range = pd.date_range(start, end)
        nan_prices = np.empty((date_range.shape[0], ))
        nan_prices[:] = np.nan
        prices = pd.DataFrame({'date' : date_range, 'close': nan_prices})
    prices = prices.sort_values(by='date')
    prices["ticker"] = ticker
    return prices[['date', 'ticker', 'close']]

# %%
pd.Timestamp("2022-12-01T12:00:00").isoformat()
# Out:
# '2022-12-01T12:00:00'

# %%
missing_names = {
 'ali': 'alethea-artificial-liquid-intelligence-token',
 'alpha': 'alphacoin',
 'ant': 'aragon',
 'arb': 'arbitrum',
 'astr': 'astar',
 'audio': 'audius',
 'axl': 'axelar',
 'blur': 'blur',
 'bond': 'barnbridge',
 # 'chromia',
 'cqt': 'covalent',
 'dydx': 'dydx',
 'legld': 'salsa-liquid-multiversx',
 'elon': 'dogelon-mars',
 # 'ethereumpow',
 'solarflare': 'flare',
 'ftm': 'fantom',
 'fxs': 'frax-share',
 'gala': 'gala',
 'ghst': 'aavegotchi',
 'glmr': 'moonbeam',
 'gmx': 'gmx',
 'hnt': 'helium',
 'icx': 'icon',
 'kava': 'kava',
 'lit': 'litentry',
 'lsk': 'lisk',
 'lunc': 'terra-luna',
 'terraport': 'terra',
 'magic': 'magic',
 'movr': 'moonriver',
 'omg': 'omisego',
 'osmo': 'osmosis',
 'pepe': 'newpepe',
 "prime": 'echelon-prime',
 'qrdo': 'qredo',
 'qtum': 'qtum',
 'ren': "republic-protocol",
 'rpl': 'rocket-pool',
 'rune': 'thorchain',
 'sc': 'siacoin',
 'sei': 'sei-network',
 'slp': 'smooth-love-potion',
 "stg": 'stargate-finance',
 "salmonation": 'sui',
 't': "threshold",
 'tvk': 'the-virtua-kolect',
 'vet': 'vechain',
 'waves':'layground-waves-floor-index',
 'xrp': 'ripple',
 'ygg': 'yield-guild-games'
}

# %%
results = []
for ticker, name in missing_names.items():
    r = requests.get(f"https://api.coingecko.com/api/v3/coins/{name}/market_chart/range?vs_currency=USD&from=1669896000&to=1701432000")
    print(f"getting data for name {name}")
    resp = r.json()
    data = resp.get('data')
    if data is None:
        prices = pd.DataFrame(resp.get('data'))
    else:
        prices = pd.DataFrame(resp.get('data')) 
    prices.columns = ["date", 'price']
    prices["date"] = pd.to_datetime(prices.date, unit='ms', origin='unix')
    prices["ticker"] = ticker
    results.append(prices)

combined_data = pd.concat(results)
# Out:
# getting data for name alethea-artificial-liquid-intelligence-token
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [40], in <cell line: 2>()
#       5 resp = r.json()
#       6 prices = pd.DataFrame(resp.get('data'))
# ----> 7 prices.columns = ["date", 'price']
#       8 prices["date"] = pd.to_datetime(prices.date, unit='ms', origin='unix')
#       9 prices["ticker"] = ticker
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/pandas/core/generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/pandas/core/generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# --> 823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/pandas/core/internals/managers.py:230, in BaseBlockManager.set_axis(self, axis, new_labels)
#     228 def set_axis(self, axis: int, new_labels: Index) -> None:
#     229     # Caller is responsible for ensuring we have an Index object.
# --> 230     self._validate_set_axis(axis, new_labels)
#     231     self.axes[axis] = new_labels
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/pandas/core/internals/base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 0 elements, new values have 2 elements

# %%
a = pd.DataFrame(results[0]['data'])

# %%
a.columns = ["date", "price"]

# %%
pd.to_datetime(a.date, unit='ms', origin='unix')
# Out:
# 0     2022-12-02
# 1     2022-12-03
# 2     2022-12-04
# 3     2022-12-05
# 4     2022-12-06
#          ...
# 360   2023-11-27
# 361   2023-11-28
# 362   2023-11-29
# 363   2023-11-30
# 364   2023-12-01
# Name: date, Length: 365, dtype: datetime64[ns]

# %%
r = requests.get(f"https://api.pro.coinbase.com/products/{ticker}/candles?start={start.isoformat()}&end={end.isoformat()}&granularity=86400")
resp = r.json()
resp
# Out:
# [[1685577600, 0.366, 0.381, 0.379, 0.367, 1553980.52],
#  [1670284800, 0.453, 0.49, 0.484, 0.475, 4997987.37],
#  [1670198400, 0.466, 0.504, 0.497, 0.484, 2897751.1],
#  [1670112000, 0.487, 0.499, 0.487, 0.497, 143168.44],
#  [1670025600, 0.481, 0.505, 0.504, 0.487, 711348.64],
#  [1669939200, 0.495, 0.512, 0.51, 0.504, 567104.25]]

# %%
start = pd.Timestamp("2022-12-01T00:00:00")
mid = pd.Timestamp("2023-06-01T00:00:00")
end = pd.Timestamp("2023-12-01T00:00:00")

prices = []
for ticker in constituents.ticker:
    print(f"get prices for: {ticker}")
    batch_1 = get_prices(ticker, start, mid)
    batch_2 = get_prices(ticker, mid + pd.Timedelta(hours=24), end)
    prices.append(pd.concat([batch_1, batch_2]))

dataset = pd.concat(prices)
dataset = dataset.pivot(index='date', columns='ticker', values='close')
#dataset = dataset.dropna(axis=1, how='all')
# Out:
# get prices for: 1INCH-USD
# found data from 1INCH-USD
# found data from 1INCH-USD
# get prices for: AAVE-USD
# found data from AAVE-USD
# found data from AAVE-USD
# get prices for: ACA-USD
# no data for ticker ACA-USD
# no data for ticker ACA-USD
# get prices for: ACH-USD
# found data from ACH-USD
# found data from ACH-USD
# get prices for: ACS-USD
# found data from ACS-USD
# found data from ACS-USD
# get prices for: ADA-USD
# found data from ADA-USD
# found data from ADA-USD
# get prices for: AERGO-USD
# found data from AERGO-USD
# found data from AERGO-USD
# get prices for: AGLD-USD
# found data from AGLD-USD
# found data from AGLD-USD
# get prices for: AKT-USD
# no data for ticker AKT-USD
# no data for ticker AKT-USD
# get prices for: ALCX-USD
# found data from ALCX-USD
# found data from ALCX-USD
# get prices for: ALGO-USD
# found data from ALGO-USD
# found data from ALGO-USD
# get prices for: ALI-USD
# no data for ticker ALI-USD
# no data for ticker ALI-USD
# get prices for: ALICE-USD
# found data from ALICE-USD
# found data from ALICE-USD
# get prices for: ALPHA-USD
# no data for ticker ALPHA-USD
# no data for ticker ALPHA-USD
# get prices for: AMP-USD
# found data from AMP-USD
# found data from AMP-USD
# get prices for: ANKR-USD
# found data from ANKR-USD
# found data from ANKR-USD
# get prices for: ANT-USD
# found data from ANT-USD
# found data from ANT-USD
# get prices for: APE-USD
# found data from APE-USD
# found data from APE-USD
# get prices for: API3-USD
# found data from API3-USD
# found data from API3-USD
# get prices for: APT-USD
# found data from APT-USD
# found data from APT-USD
# get prices for: ARB-USD
# found data from ARB-USD
# found data from ARB-USD
# get prices for: ARPA-USD
# found data from ARPA-USD
# found data from ARPA-USD
# get prices for: ASTR-USD
# no data for ticker ASTR-USD
# no data for ticker ASTR-USD
# get prices for: ATOM-USD
# found data from ATOM-USD
# found data from ATOM-USD
# get prices for: AUDIO-USD
# found data from AUDIO-USD
# found data from AUDIO-USD
# get prices for: AURORA-USD
# found data from AURORA-USD
# found data from AURORA-USD
# get prices for: AVAX-USD
# found data from AVAX-USD
# found data from AVAX-USD
# get prices for: AXL-USD
# found data from AXL-USD
# found data from AXL-USD
# get prices for: AXS-USD
# found data from AXS-USD
# found data from AXS-USD
# get prices for: BADGER-USD
# found data from BADGER-USD
# found data from BADGER-USD
# get prices for: BAL-USD
# found data from BAL-USD
# found data from BAL-USD
# get prices for: BAND-USD
# found data from BAND-USD
# found data from BAND-USD
# get prices for: BAT-USD
# found data from BAT-USD
# found data from BAT-USD
# get prices for: BCH-USD
# found data from BCH-USD
# found data from BCH-USD
# get prices for: BICO-USD
# found data from BICO-USD
# found data from BICO-USD
# get prices for: BLUR-USD
# found data from BLUR-USD
# found data from BLUR-USD
# get prices for: BLZ-USD
# found data from BLZ-USD
# found data from BLZ-USD
# get prices for: BNT-USD
# found data from BNT-USD
# found data from BNT-USD
# get prices for: BOND-USD
# found data from BOND-USD
# found data from BOND-USD
# get prices for: BTC-USD
# found data from BTC-USD
# found data from BTC-USD
# get prices for: C98-USD
# found data from C98-USD
# found data from C98-USD
# get prices for: CELR-USD
# found data from CELR-USD
# found data from CELR-USD
# get prices for: CHR-USD
# no data for ticker CHR-USD
# no data for ticker CHR-USD
# get prices for: CHZ-USD
# found data from CHZ-USD
# found data from CHZ-USD
# get prices for: COMP-USD
# found data from COMP-USD
# found data from COMP-USD
# get prices for: COTI-USD
# found data from COTI-USD
# found data from COTI-USD
# get prices for: CQT-USD
# no data for ticker CQT-USD
# no data for ticker CQT-USD
# get prices for: CRO-USD
# found data from CRO-USD
# found data from CRO-USD
# get prices for: CRV-USD
# found data from CRV-USD
# found data from CRV-USD
# get prices for: CTSI-USD
# found data from CTSI-USD
# found data from CTSI-USD
# get prices for: CVC-USD
# found data from CVC-USD
# found data from CVC-USD
# get prices for: CVX-USD
# found data from CVX-USD
# found data from CVX-USD
# get prices for: DAR-USD
# found data from DAR-USD
# found data from DAR-USD
# get prices for: DASH-USD
# found data from DASH-USD
# found data from DASH-USD
# get prices for: DIA-USD
# found data from DIA-USD
# found data from DIA-USD
# get prices for: DOGE-USD
# found data from DOGE-USD
# found data from DOGE-USD
# get prices for: DOT-USD
# found data from DOT-USD
# found data from DOT-USD
# get prices for: DYDX-USD
# no data for ticker DYDX-USD
# no data for ticker DYDX-USD
# get prices for: EGLD-USD
# found data from EGLD-USD
# found data from EGLD-USD
# get prices for: ELON-USD
# no data for ticker ELON-USD
# no data for ticker ELON-USD
# get prices for: ENJ-USD
# found data from ENJ-USD
# found data from ENJ-USD
# get prices for: ENS-USD
# found data from ENS-USD
# found data from ENS-USD
# get prices for: EOS-USD
# found data from EOS-USD
# found data from EOS-USD
# get prices for: ERN-USD
# found data from ERN-USD
# found data from ERN-USD
# get prices for: ETC-USD
# found data from ETC-USD
# found data from ETC-USD
# get prices for: ETH-USD
# found data from ETH-USD
# found data from ETH-USD
# get prices for: ETHW-USD
# no data for ticker ETHW-USD
# no data for ticker ETHW-USD
# get prices for: FET-USD
# found data from FET-USD
# found data from FET-USD
# get prices for: FIL-USD
# found data from FIL-USD
# found data from FIL-USD
# get prices for: FLOW-USD
# found data from FLOW-USD
# found data from FLOW-USD
# get prices for: FLR-USD
# found data from FLR-USD
# found data from FLR-USD
# get prices for: FORTH-USD
# found data from FORTH-USD
# found data from FORTH-USD
# get prices for: FTM-USD
# no data for ticker FTM-USD
# no data for ticker FTM-USD
# get prices for: FXS-USD
# no data for ticker FXS-USD
# no data for ticker FXS-USD
# get prices for: GAL-USD
# found data from GAL-USD
# found data from GAL-USD
# get prices for: GALA-USD
# found data from GALA-USD
# no data for ticker GALA-USD
# get prices for: GHST-USD
# found data from GHST-USD
# found data from GHST-USD
# get prices for: GLM-USD
# found data from GLM-USD
# found data from GLM-USD
# get prices for: GLMR-USD
# no data for ticker GLMR-USD
# no data for ticker GLMR-USD
# get prices for: GMT-USD
# found data from GMT-USD
# found data from GMT-USD
# get prices for: GMX-USD
# no data for ticker GMX-USD
# no data for ticker GMX-USD
# get prices for: GNO-USD
# found data from GNO-USD
# found data from GNO-USD
# get prices for: GODS-USD
# found data from GODS-USD
# found data from GODS-USD
# get prices for: GRT-USD
# found data from GRT-USD
# found data from GRT-USD
# get prices for: GTC-USD
# found data from GTC-USD
# found data from GTC-USD
# get prices for: HBAR-USD
# found data from HBAR-USD
# found data from HBAR-USD
# get prices for: HFT-USD
# found data from HFT-USD
# found data from HFT-USD
# get prices for: HIGH-USD
# found data from HIGH-USD
# found data from HIGH-USD
# get prices for: HNT-USD
# no data for ticker HNT-USD
# found data from HNT-USD
# get prices for: ICP-USD
# found data from ICP-USD
# found data from ICP-USD
# get prices for: ICX-USD
# no data for ticker ICX-USD
# no data for ticker ICX-USD
# get prices for: IDEX-USD
# found data from IDEX-USD
# found data from IDEX-USD
# get prices for: ILV-USD
# found data from ILV-USD
# found data from ILV-USD
# get prices for: IMX-USD
# found data from IMX-USD
# found data from IMX-USD
# get prices for: INJ-USD
# found data from INJ-USD
# found data from INJ-USD
# get prices for: IOTX-USD
# found data from IOTX-USD
# found data from IOTX-USD
# get prices for: JASMY-USD
# found data from JASMY-USD
# found data from JASMY-USD
# get prices for: KAVA-USD
# found data from KAVA-USD
# found data from KAVA-USD
# get prices for: KNC-USD
# found data from KNC-USD
# found data from KNC-USD
# get prices for: KSM-USD
# found data from KSM-USD
# found data from KSM-USD
# get prices for: LCX-USD
# found data from LCX-USD
# found data from LCX-USD
# get prices for: LDO-USD
# found data from LDO-USD
# found data from LDO-USD
# get prices for: LINK-USD
# found data from LINK-USD
# found data from LINK-USD
# get prices for: LIT-USD
# found data from LIT-USD
# found data from LIT-USD
# get prices for: LPT-USD
# found data from LPT-USD
# found data from LPT-USD
# get prices for: LQTY-USD
# found data from LQTY-USD
# found data from LQTY-USD
# get prices for: LRC-USD
# found data from LRC-USD
# found data from LRC-USD
# get prices for: LSK-USD
# no data for ticker LSK-USD
# no data for ticker LSK-USD
# get prices for: LTC-USD
# found data from LTC-USD
# found data from LTC-USD
# get prices for: LUNC-USD
# no data for ticker LUNC-USD
# no data for ticker LUNC-USD
# get prices for: LUNA-USD
# no data for ticker LUNA-USD
# no data for ticker LUNA-USD
# get prices for: MAGIC-USD
# found data from MAGIC-USD
# found data from MAGIC-USD
# get prices for: MANA-USD
# found data from MANA-USD
# found data from MANA-USD
# get prices for: MASK-USD
# found data from MASK-USD
# found data from MASK-USD
# get prices for: MATIC-USD
# found data from MATIC-USD
# found data from MATIC-USD
# get prices for: MDT-USD
# found data from MDT-USD
# found data from MDT-USD
# get prices for: METIS-USD
# found data from METIS-USD
# found data from METIS-USD
# get prices for: MINA-USD
# found data from MINA-USD
# found data from MINA-USD
# get prices for: MKR-USD
# found data from MKR-USD
# found data from MKR-USD
# get prices for: MLN-USD
# found data from MLN-USD
# found data from MLN-USD
# get prices for: MOVR-USD
# no data for ticker MOVR-USD
# no data for ticker MOVR-USD
# get prices for: NEAR-USD
# found data from NEAR-USD
# found data from NEAR-USD
# get prices for: NKN-USD
# found data from NKN-USD
# found data from NKN-USD
# get prices for: NMR-USD
# found data from NMR-USD
# found data from NMR-USD
# get prices for: OCEAN-USD
# found data from OCEAN-USD
# found data from OCEAN-USD
# get prices for: OGN-USD
# found data from OGN-USD
# found data from OGN-USD
# get prices for: OMG-USD
# found data from OMG-USD
# no data for ticker OMG-USD
# get prices for: OP-USD
# found data from OP-USD
# found data from OP-USD
# get prices for: OSMO-USD
# found data from OSMO-USD
# found data from OSMO-USD
# get prices for: OXT-USD
# found data from OXT-USD
# found data from OXT-USD
# get prices for: PEPE-USD
# no data for ticker PEPE-USD
# no data for ticker PEPE-USD
# get prices for: PERP-USD
# found data from PERP-USD
# found data from PERP-USD
# get prices for: PLA-USD
# found data from PLA-USD
# found data from PLA-USD
# get prices for: POLS-USD
# found data from POLS-USD
# found data from POLS-USD
# get prices for: POND-USD
# found data from POND-USD
# found data from POND-USD
# get prices for: POWR-USD
# found data from POWR-USD
# found data from POWR-USD
# get prices for: PRIME-USD
# found data from PRIME-USD
# found data from PRIME-USD
# get prices for: PYR-USD
# found data from PYR-USD
# found data from PYR-USD
# get prices for: QNT-USD
# found data from QNT-USD
# found data from QNT-USD
# get prices for: QRDO-USD
# no data for ticker QRDO-USD
# no data for ticker QRDO-USD
# get prices for: QTUM-USD
# no data for ticker QTUM-USD
# no data for ticker QTUM-USD
# get prices for: RAD-USD
# found data from RAD-USD
# found data from RAD-USD
# get prices for: RARE-USD
# found data from RARE-USD
# found data from RARE-USD
# get prices for: RBN-USD
# found data from RBN-USD
# found data from RBN-USD
# get prices for: REN-USD
# found data from REN-USD
# found data from REN-USD
# get prices for: REQ-USD
# found data from REQ-USD
# found data from REQ-USD
# get prices for: RLC-USD
# found data from RLC-USD
# found data from RLC-USD
# get prices for: RNDR-USD
# found data from RNDR-USD
# found data from RNDR-USD
# get prices for: RPL-USD
# found data from RPL-USD
# found data from RPL-USD
# get prices for: RUNE-USD
# no data for ticker RUNE-USD
# no data for ticker RUNE-USD
# get prices for: SAND-USD
# found data from SAND-USD
# found data from SAND-USD
# get prices for: SC-USD
# no data for ticker SC-USD
# no data for ticker SC-USD
# get prices for: SEI-USD
# no data for ticker SEI-USD
# found data from SEI-USD
# get prices for: SHIB-USD
# found data from SHIB-USD
# found data from SHIB-USD
# get prices for: SKL-USD
# found data from SKL-USD
# found data from SKL-USD
# get prices for: SLP-USD
# no data for ticker SLP-USD
# no data for ticker SLP-USD
# get prices for: SNT-USD
# found data from SNT-USD
# found data from SNT-USD
# get prices for: SNX-USD
# found data from SNX-USD
# found data from SNX-USD
# get prices for: SOL-USD
# found data from SOL-USD
# found data from SOL-USD
# get prices for: SPELL-USD
# found data from SPELL-USD
# found data from SPELL-USD
# get prices for: STG-USD
# found data from STG-USD
# no data for ticker STG-USD
# get prices for: STORJ-USD
# found data from STORJ-USD
# found data from STORJ-USD
# get prices for: STX-USD
# found data from STX-USD
# found data from STX-USD
# get prices for: SUI-USD
# found data from SUI-USD
# found data from SUI-USD
# get prices for: SUSHI-USD
# found data from SUSHI-USD
# found data from SUSHI-USD
# get prices for: SYN-USD
# found data from SYN-USD
# found data from SYN-USD
# get prices for: T-USD
# found data from T-USD
# found data from T-USD
# get prices for: TRB-USD
# found data from TRB-USD
# found data from TRB-USD
# get prices for: TRU-USD
# found data from TRU-USD
# found data from TRU-USD
# get prices for: TVK-USD
# found data from TVK-USD
# found data from TVK-USD
# get prices for: UMA-USD
# found data from UMA-USD
# found data from UMA-USD
# get prices for: UNFI-USD
# found data from UNFI-USD
# found data from UNFI-USD
# get prices for: UNI-USD
# found data from UNI-USD
# found data from UNI-USD
# get prices for: VET-USD
# no data for ticker VET-USD
# found data from VET-USD
# get prices for: WAVES-USD
# no data for ticker WAVES-USD
# no data for ticker WAVES-USD
# get prices for: WOO-USD
# no data for ticker WOO-USD
# no data for ticker WOO-USD
# get prices for: XLM-USD
# found data from XLM-USD
# found data from XLM-USD
# get prices for: XRP-USD
# no data for ticker XRP-USD
# found data from XRP-USD
# get prices for: XTZ-USD
# found data from XTZ-USD
# found data from XTZ-USD
# get prices for: XYO-USD
# found data from XYO-USD
# found data from XYO-USD
# get prices for: YFI-USD
# found data from YFI-USD
# found data from YFI-USD
# get prices for: YGG-USD
# no data for ticker YGG-USD
# no data for ticker YGG-USD
# get prices for: ZEC-USD
# found data from ZEC-USD
# found data from ZEC-USD
# get prices for: ZRX-USD
# found data from ZRX-USD
# found data from ZRX-USD

# %%
dataset.to_csv("coinbase_prices.csv")
# Out:
# /Users/kevingivens/anaconda3/envs/py10/lib/python3.10/site-packages/pandas/core/internals/blocks.py:2323: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)

# %%
dataset = pd.read_csv("coinbase_prices.csv")

# %%
dataset.columns[dataset.isna().any()]
# Out:
# Index(['ACA-USD', 'ACS-USD', 'AKT-USD', 'ALI-USD', 'ALPHA-USD', 'ANT-USD',
#        'ARB-USD', 'ASTR-USD', 'AUDIO-USD', 'AXL-USD', 'BLUR-USD', 'BOND-USD',
#        'CHR-USD', 'CQT-USD', 'DYDX-USD', 'EGLD-USD', 'ELON-USD', 'ETHW-USD',
#        'FLR-USD', 'FTM-USD', 'FXS-USD', 'GALA-USD', 'GHST-USD', 'GLMR-USD',
#        'GMX-USD', 'HNT-USD', 'ICX-USD', 'KAVA-USD', 'LIT-USD', 'LSK-USD',
#        'LUNA-USD', 'LUNC-USD', 'MAGIC-USD', 'MOVR-USD', 'OMG-USD', 'OSMO-USD',
#        'PEPE-USD', 'PRIME-USD', 'QRDO-USD', 'QTUM-USD', 'REN-USD', 'RPL-USD',
#        'RUNE-USD', 'SC-USD', 'SEI-USD', 'SLP-USD', 'STG-USD', 'SUI-USD',
#        'T-USD', 'TVK-USD', 'VET-USD', 'WAVES-USD', 'WOO-USD', 'XRP-USD',
#        'YGG-USD'],
#       dtype='object')

# %%
prods = pd.DataFrame.from_records(resp)

# %%
prods
# Out:
#             id base_currency quote_currency quote_increment base_increment  \
# 0     ANKR-USD          ANKR            USD         0.00001              1
# 1     FIDA-EUR          FIDA            EUR          0.0001           0.01
# 2     ADA-USDC           ADA           USDC           0.001           0.01
# 3      MIR-EUR           MIR            EUR           0.001           0.01
# 4    LSETH-ETH         LSETH            ETH         0.00001        0.00001
# ..         ...           ...            ...             ...            ...
# 603    UNI-USD           UNI            USD           0.001       0.000001
# 604   GNO-USDT           GNO           USDT            0.01         0.0001
# 605    RBN-USD           RBN            USD         0.00001           0.01
# 606    UPI-USD           UPI            USD         0.00001              1
# 607   MSOL-USD          MSOL            USD            0.01          0.001
#
#     display_name min_market_funds  margin_enabled  post_only  limit_only  \
# 0       ANKR/USD                1           False      False       False
# 1       FIDA/EUR                1           False      False       False
# 2       ADA/USDC                1           False      False       False
# 3        MIR/EUR             0.84           False      False       False
# 4      LSETH/ETH            0.002           False      False        True
# ..           ...              ...             ...        ...         ...
# 603      UNI/USD                1           False      False       False
# 604     GNO/USDT                1           False      False       False
# 605      RBN/USD                1           False      False       False
# 606      UPI/USD                1           False      False       False
# 607     MSOL/USD                1           False      False       False
#
#      cancel_only    status status_message  trading_disabled  fx_stablecoin  \
# 0          False    online                            False          False
# 1          False  delisted                             True          False
# 2          False  delisted                             True          False
# 3          False  delisted                             True          False
# 4          False    online                            False           True
# ..           ...       ...            ...               ...            ...
# 603        False    online                            False          False
# 604        False  delisted                             True          False
# 605        False    online                            False          False
# 606        False  delisted                             True          False
# 607        False    online                            False          False
#
#     max_slippage_percentage  auction_mode high_bid_limit_percentage
# 0                0.03000000         False
# 1                0.03000000         False
# 2                0.03000000         False
# 3                0.03000000         False
# 4                0.01000000         False
# ..                      ...           ...                       ...
# 603              0.03000000         False
# 604              0.03000000         False
# 605              0.03000000         False
# 606              0.03000000         False
# 607              0.03000000         False
#
# [608 rows x 18 columns]

# %%
prods[prods.display_name.str.contains('WOO')]
# Out:
# Empty DataFrame
# Columns: [id, base_currency, quote_currency, quote_increment, base_increment, display_name, min_market_funds, margin_enabled, post_only, limit_only, cancel_only, status, status_message, trading_disabled, fx_stablecoin, max_slippage_percentage, auction_mode, high_bid_limit_percentage]
# Index: []

# %%
dataset1.pct_change().iloc[1:]
# Out:
# ticker      1INCH-USD  AAVE-USD   ACH-USD   ADA-USD  AERGO-USD  AGLD-USD  \
# date
# 2022-12-02  -0.011765  0.032207 -0.004974  0.014626   0.016755  0.012332
# 2022-12-03  -0.033730 -0.044749 -0.031990  0.001567  -0.016479 -0.025439
# 2022-12-04   0.020534  0.026131  0.013942  0.008761  -0.011464  0.015441
# 2022-12-05  -0.026157 -0.000621 -0.023630 -0.008995  -0.014273  0.166908
#
# [365 rows x 129 columns]

# %%
constituents.head()
# Out:
#   Symbol             Name              DACS Sector DACS Industry Group  \
# 0  1inch    1inch Network                     DeFi           Exchanges
# 1   aave             Aave                     DeFi     Credit Platform
# 2    aca      Acala Token  Smart Contract Platform             Layer 1
# 3    ach      Alchemy Pay                 Currency                BaaS
# 4    acs  Access Protocol  Culture & Entertainment               Media
#
#          DACS Industry  Reconstitution Weight
# 0    Exchanges (Other)               0.032945
# 1  Lending / Borrowing               0.108995
# 2              Layer 1               0.006482
# 3             Payments               0.011424
# 4               Social               0.007609

# %% [markdown]
# ## Learning a graph structure
#
# We use sparse inverse covariance estimation to find which quotes are
# correlated conditionally on the others. Specifically, sparse inverse
# covariance gives us a graph, that is a list of connections. For each
# symbol, the symbols that it is connected to are those useful to explain
# its fluctuations.

# %%
dataset1
# Out:
# ticker      1INCH-USD  AAVE-USD   ACH-USD  ADA-USD  AERGO-USD  AGLD-USD  \
# date
# 2022-12-01      0.510     63.65  0.010053   0.3145     0.1134    0.2757
# 2022-12-02      0.504     65.70  0.010003   0.3191     0.1153    0.2791
# 2022-12-03      0.487     62.76  0.009683   0.3196     0.1134    0.2720
# 2022-12-04      0.497     64.40  0.009818   0.3224     0.1121    0.2762
# 2022-12-05      0.484     64.36  0.009586   0.3195     0.1105    0.3223
# ...               ...       ...       ...      ...        ...       ...
# 2023-11-27      0.345     97.23  0.019895   0.3777     0.1655    0.8480
# 2023-11-28      0.343     96.97  0.020228   0.3859     0.1725    0.8322
# 2023-11-29      0.342     96.47  0.019862   0.3817     0.1859    0.8228
# 2023-11-30      0.341     98.29  0.019865   0.3760     0.1900    0.8270
# 2023-12-01      0.351    100.21  0.020380   0.3845     0.1915    0.8441
#
# ticker      ALCX-USD  ALGO-USD  ALICE-USD  AMP-USD  ...  TRU-USD  UMA-USD  \
# date                                                ...
# 2022-12-01     18.01    0.2408      1.324  0.00354  ...   0.0384    1.714
# 2022-12-02     18.79    0.2441      1.363  0.00353  ...   0.0395    1.715
# 2022-12-03     18.04    0.2377      1.323  0.00349  ...   0.0385    1.687
# 2022-12-04     18.64    0.2394      1.357  0.00351  ...   0.0390    1.719
# 2022-12-05     18.34    0.2364      1.372  0.00350  ...   0.0386    1.709
# ...              ...       ...        ...      ...  ...      ...      ...
# 2023-11-27     15.74    0.1317      1.188  0.00241  ...   0.0605    1.812
# 2023-11-28     15.86    0.1330      1.143  0.00247  ...   0.0568    1.945
# 2023-11-29     15.55    0.1342      1.109  0.00255  ...   0.0574    1.939
# 2023-11-30     15.75    0.1337      1.090  0.00249  ...   0.0576    1.929
# 2023-12-01     20.55    0.1397      1.110  0.00247  ...   0.0570    1.939
#
# ticker      UNFI-USD  UNI-USD   XLM-USD  XTZ-USD  XYO-USD  YFI-USD  ZEC-USD  \
# date
# 2022-12-01      4.65    5.918  0.087632    1.004  0.00432  6699.09    44.92
# 2022-12-02      4.68    6.345  0.088096    1.029  0.00433  6800.23    46.12
# 2022-12-03      4.51    6.092  0.086310    0.993  0.00429  6627.07    45.51
# 2022-12-04      4.63    6.261  0.087659    1.005  0.00445  7323.88    45.85
# 2022-12-05      4.80    6.172  0.086940    1.006  0.00428  7152.54    46.43
# ...              ...      ...       ...      ...      ...      ...      ...
# 2023-11-27     12.39    6.290  0.116499    0.808  0.00387  8436.94    28.77
# 2023-11-28     12.84    6.175  0.118565    0.816  0.00388  8481.35    29.01
# 2023-11-29     11.90    6.014  0.118537    0.825  0.00590  8289.87    29.09
# 2023-11-30     11.59    5.960  0.118309    0.832  0.00686  8256.77    29.47
# 2023-12-01     11.74    6.017  0.119819    0.844  0.00711  8464.00    29.77
#
# ticker       ZRX-USD
# date
# 2022-12-01  0.193194
# 2022-12-02  0.192361
# 2022-12-03  0.189207
# 2022-12-04  0.195823
# 2022-12-05  0.191428
# ...              ...
# 2023-11-27  0.391225
# 2023-11-28  0.396697
# 2023-11-29  0.396890
# 2023-11-30  0.382034
# 2023-12-01  0.403500
#
# [366 rows x 129 columns]

# %%
X = dataset1.values 
emp_cov = covariance.EmpiricalCovariance()

cov = emp_cov.fit(X)
cov.covariance_
# Out:
# /Users/kevingivens/anaconda3/envs/py10/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# array([[1.19662539e-02, 6.22788128e-01, 5.36003167e-04, ...,
#         1.07459506e+02, 6.97347534e-01, 1.95976255e-03],
#        [6.22788128e-01, 1.51263491e+02, 3.71860883e-02, ...,
#         1.12312601e+04, 2.65015843e+01, 5.96867397e-01],
#        [5.36003167e-04, 3.71860883e-02, 8.52180868e-05, ...,
#         8.75178591e+00, 9.16463645e-03, 2.36777436e-04],
#        ...,
#        [1.07459506e+02, 1.12312601e+04, 8.75178591e+00, ...,
#         2.10935401e+06, 4.39697223e+03, 6.56726911e+01],
#        [6.97347534e-01, 2.65015843e+01, 9.16463645e-03, ...,
#         4.39697223e+03, 5.22123191e+01, 2.61586639e-02],
#        [1.95976255e-03, 5.96867397e-01, 2.36777436e-04, ...,
#         6.56726911e+01, 2.61586639e-02, 3.90810946e-03]])

# %%
rets = dataset.pct_change().iloc[1:]
cov = rets.cov()

# %%
alphas = np.logspace(-1.5, 1, num=10)
edge_model = covariance.GraphicalLassoCV(alphas=alphas)

# standardize the time series: using correlations rather than covariance
# former is more efficient for structure recovery
X = variation.copy().T
X /= X.std(axis=0)
edge_model.fit(X)

# %% [markdown]
# ## Clustering using affinity propagation
#
# We use clustering to group together quotes that behave similarly. Here,
# amongst the `various clustering techniques <clustering>` available
# in the scikit-learn, we use `affinity_propagation` as it does
# not enforce equal-size clusters, and it can choose automatically the
# number of clusters from the data.
#
# Note that this gives us a different indication than the graph, as the
# graph reflects conditional relations between variables, while the
# clustering reflects marginal properties: variables clustered together can
# be considered as having a similar impact at the level of the full stock
# market.

# %%
#_, labels = cluster.affinity_propagation(edge_model.covariance_, random_state=0)
_, labels = cluster.affinity_propagation(cov, random_state=0)
n_labels = labels.max()

for i in range(n_labels + 1):
    print(f"Cluster {i + 1}: {', '.join(cov.index.values[labels == i])}")
# Out:
# Cluster 1: 0x, ARPA, Aave, Aavegotchi, Aergo, Akash Network, Alchemy Pay, Algorand, Alpha Coin, Amp, Ampleforth Governance Token, Ankr, Aptos, Artificial Liquid Intelligence, Astar, Audius, Avalanche, Axie Infinity, Badger DAO, Balancer, Bancor, Band Protocol, BarnBridge, Basic Attention Token, Biconomy, Bitcoin, Bitcoin Cash, Bluzelle, COTI, Cardano, Cartesi, Celer Network, Chainlink, Chiliz, Chromia, Civic, Coin98, Compound, Convex Finance, Cosmos, Covalent, Cronos, Dash, Decentraland, Dogecoin, Dogelon Mars, EOS, Enjin Coin, Enzyme, Ethereum Classic, Ethereum Name Service, Ethernity Chain, Fantom, Fetch.ai, Filecoin, Flow, Frax Share, GMT, GMX, Galxe, Gitcoin, Gods Unchained, Golem, Hashflow, Hedera, Helium, Highstreet, ICON, IDEX, Illuvium, Immutable X, Injective, Internet Computer, IoTeX, JasmyCoin, Kava, Kusama, Kyber Network Crystal, Lido DAO, Liquity, Lisk, Litecoin, Litentry, Livepeer, Loopring, MAGIC, Mask Network, Mina, Mines of Dalarnia, Moonbeam, Moonriver, MultiversX, My Neighbor Alice, NEAR Protocol, NKN, Numeraire, OMG Network, Ocean Protocol, Optimism, Orchid, Origin Protocol, PlayDapp, Polkadot, Polygon, Powerledger, Qredo, Qtum, Radworks, Ren, Render Token, Request, Rocket Pool, SKALE, Siacoin, Smooth Love Potion, Solana, Spell Token, Stacks, Stargate Finance, Status, Stellar, Storj, SushiSwap, Synapse, Synthetix, THORChain, Terra, Terra Luna Classic, Tezos, The Sandbox, The Virtua Kolect, Threshold, TrueFi, UMA, Unifi Protocol DAO, Uniswap, VeChain, Vulcan Forged PYR, WOO Network, Waves, XRP, XYO, Yield Guild Games, Zcash, iExec RLC
# Cluster 2: Axelar
# Cluster 3: Ethereum
# Cluster 4: ApeCoin, Aragon, Aurora, Curve DAO Token, EthereumPoW, Gala, LCX, Polkastarter, SHIBA INU, yearn.finance
# Cluster 5: Gnosis
# Cluster 6: Quant
# Cluster 7: Ribbon Finance
# Cluster 8: API3, Acala Token, Alchemix, Maker, Perpetual Protocol, Tellor
# Cluster 9: 1inch Network, Adventure Gold, DIA, Marlin, Measurable Data Token, MetisDAO, Osmosis, SuperRare, The Graph

# %%
cov
# Out:
# ticker      1INCH-USD      AAVE-USD   ACH-USD    ADA-USD  AERGO-USD  \
# ticker
# 1INCH-USD    0.011999      0.624494  0.000537   0.004638   0.001231
# AAVE-USD     0.624494    151.677912  0.037288   0.452713   0.239238
# ACH-USD      0.000537      0.037288  0.000085   0.000319   0.000090
# ADA-USD      0.004638      0.452713  0.000319   0.002943   0.000901
# AERGO-USD    0.001231      0.239238  0.000090   0.000901   0.000486
# ...               ...           ...       ...        ...        ...
# XTZ-USD      0.018066      1.088445  0.001003   0.007525   0.002057
# XYO-USD      0.000108      0.006587  0.000003   0.000043   0.000012
# YFI-USD    107.753915  11262.030654  8.775763  59.828233  23.925001
# ZEC-USD      0.699258     26.574191  0.009190   0.219449   0.047387
# ZRX-USD      0.001965      0.598503  0.000237   0.002145   0.001233
#
# ticker      AGLD-USD     ALCX-USD   ALGO-USD   ALICE-USD   AMP-USD  ...  \
# ticker                                                              ...
# 1INCH-USD  -0.007304     0.359878   0.005949    0.039204  0.000116  ...
# AAVE-USD    1.055477    22.537626   0.253925    2.022751  0.005015  ...
# ACH-USD     0.000165     0.020700   0.000178    0.001945  0.000004  ...
# ADA-USD    -0.000111     0.151855   0.002049    0.016127  0.000039  ...
# AERGO-USD   0.001540     0.044317   0.000503    0.004051  0.000010  ...
# ...              ...          ...        ...         ...       ...  ...
# XTZ-USD    -0.008394     0.572445   0.008780    0.060722  0.000177  ...
# XYO-USD    -0.000076     0.003216   0.000057    0.000367  0.000001  ...
# YFI-USD    28.362326  3722.076263  45.631626  355.573546  0.972934  ...
# ZEC-USD    -0.667286    18.805195   0.384900    2.252644  0.007239  ...
# ZRX-USD     0.005601     0.079918   0.000571    0.006163  0.000010  ...
#
# ticker       TRU-USD     UMA-USD    UNFI-USD     UNI-USD   XLM-USD  \
# ticker
# 1INCH-USD   0.001328    0.027547   -0.034584    0.073282 -0.001075
# AAVE-USD    0.094622    1.680298   13.269469    5.297721  0.046068
# ACH-USD     0.000143    0.001822   -0.000730    0.002281 -0.000013
# ADA-USD     0.000586    0.014165    0.011940    0.029624 -0.000162
# AERGO-USD   0.000199    0.003697    0.024381    0.008835  0.000040
# ...              ...         ...         ...         ...       ...
# XTZ-USD     0.002337    0.043944   -0.051084    0.117488 -0.001255
# XYO-USD     0.000010    0.000241   -0.000221    0.000743 -0.000011
# YFI-USD    20.522608  305.675793  367.858069  743.411035 -2.092490
# ZEC-USD     0.039401    1.361224   -3.615688    4.717113 -0.079505
# ZRX-USD     0.000469    0.007634    0.071562    0.015031  0.000267
#
# ticker        XTZ-USD   XYO-USD       YFI-USD      ZEC-USD    ZRX-USD
# ticker
# 1INCH-USD    0.018066  0.000108  1.077539e+02     0.699258   0.001965
# AAVE-USD     1.088445  0.006587  1.126203e+04    26.574191   0.598503
# ACH-USD      0.001003  0.000003  8.775763e+00     0.009190   0.000237
# ADA-USD      0.007525  0.000043  5.982823e+01     0.219449   0.002145
# AERGO-USD    0.002057  0.000012  2.392500e+01     0.047387   0.001233
# ...               ...       ...           ...          ...        ...
# XTZ-USD      0.029559  0.000162  1.853410e+02     0.982486   0.003591
# XYO-USD      0.000162  0.000001  9.004531e-01     0.006801   0.000017
# YFI-USD    185.340958  0.900453  2.115133e+06  4409.018733  65.852616
# ZEC-USD      0.982486  0.006801  4.409019e+03    52.355367   0.026230
# ZRX-USD      0.003591  0.000017  6.585262e+01     0.026230   0.003919
#
# [129 rows x 129 columns]

# %%
symbol_dict = { 
    "SNY": "Sanofi-Aventis",
    "NVS": "Novartis",
    "KMB": "Kimberly-Clark",
    "R": "Ryder",
    "GD": "General Dynamics",
    "RTN": "Raytheon",
    "CVS": "CVS",
    "CAT": "Caterpillar",
    "DD": "DuPont de Nemours",
}


symbols, names = np.array(sorted(symbol_dict.items())).T

# %%
names
# Out:
# array(['Caterpillar', 'CVS', 'DuPont de Nemours', 'General Dynamics',
#        'Kimberly-Clark', 'Novartis', 'Ryder', 'Raytheon',
#        'Sanofi-Aventis'], dtype='<U17')

# %% [markdown]
# ## Embedding in 2D space
#
# For visualization purposes, we need to lay out the different symbols on a
# 2D canvas. For this we use `manifold` techniques to retrieve 2D
# embedding.
# We use a dense eigen_solver to achieve reproducibility (arpack is initiated
# with the random vectors that we don't control). In addition, we use a large
# number of neighbors to capture the large-scale structure.

# %%
# Finding a low-dimension embedding for visualization: find the best position of
# the nodes (the stocks) on a 2D plane


node_position_model = manifold.LocallyLinearEmbedding(
    n_components=2, eigen_solver="dense", n_neighbors=10
)

embedding = node_position_model.fit_transform(X.T).T

# %% [markdown]
# ## Visualization
#
# The output of the 3 models are combined in a 2D graph where nodes
# represents the stocks and edges the:
#
# - cluster labels are used to define the color of the nodes
# - the sparse covariance model is used to display the strength of the edges
# - the 2D embedding is used to position the nodes in the plan
#
# This example has a fair amount of visualization-related code, as
# visualization is crucial here to display the graph. One of the challenge
# is to position the labels minimizing overlap. For this we use an
# heuristic based on the direction of the nearest neighbor along each
# axis.

# %%
plt.figure(1, facecolor="w", figsize=(10, 8))
plt.clf()
ax = plt.axes([0.0, 0.0, 1.0, 1.0])
plt.axis("off")

# Plot the graph of partial correlations
partial_correlations = edge_model.precision_.copy()
d = 1 / np.sqrt(np.diag(partial_correlations))
partial_correlations *= d
partial_correlations *= d[:, np.newaxis]
non_zero = np.abs(np.triu(partial_correlations, k=1)) > 0.02

# Plot the nodes using the coordinates of our embedding
plt.scatter(
    embedding[0], embedding[1], s=100 * d**2, c=labels, cmap=plt.cm.nipy_spectral
)

# Plot the edges
start_idx, end_idx = np.where(non_zero)
# a sequence of (*line0*, *line1*, *line2*), where::
#            linen = (x0, y0), (x1, y1), ... (xm, ym)
segments = [
    [embedding[:, start], embedding[:, stop]] for start, stop in zip(start_idx, end_idx)
]
values = np.abs(partial_correlations[non_zero])
lc = LineCollection(
    segments, zorder=0, cmap=plt.cm.hot_r, norm=plt.Normalize(0, 0.7 * values.max())
)
lc.set_array(values)
lc.set_linewidths(15 * values)
ax.add_collection(lc)

# Add a label to each node. The challenge here is that we want to
# position the labels to avoid overlap with other labels
for index, (name, label, (x, y)) in enumerate(zip(names, labels, embedding.T)):
    dx = x - embedding[0]
    dx[index] = 1
    dy = y - embedding[1]
    dy[index] = 1
    this_dx = dx[np.argmin(np.abs(dy))]
    this_dy = dy[np.argmin(np.abs(dx))]
    if this_dx > 0:
        horizontalalignment = "left"
        x = x + 0.002
    else:
        horizontalalignment = "right"
        x = x - 0.002
    if this_dy > 0:
        verticalalignment = "bottom"
        y = y + 0.002
    else:
        verticalalignment = "top"
        y = y - 0.002
    plt.text(
        x,
        y,
        name,
        size=10,
        horizontalalignment=horizontalalignment,
        verticalalignment=verticalalignment,
        bbox=dict(
            facecolor="w",
            edgecolor=plt.cm.nipy_spectral(label / float(n_labels)),
            alpha=0.6,
        ),
    )

plt.xlim(
    embedding[0].min() - 0.15 * embedding[0].ptp(),
    embedding[0].max() + 0.10 * embedding[0].ptp(),
)
plt.ylim(
    embedding[1].min() - 0.03 * embedding[1].ptp(),
    embedding[1].max() + 0.03 * embedding[1].ptp(),
)

plt.show()
